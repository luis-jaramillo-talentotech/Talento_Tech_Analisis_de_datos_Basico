# %% [markdown]
# <a href="https://colab.research.google.com/github/luis-jaramillo-talentotech/Talento_Tech_Analisis_de_datos_Basico/blob/main/Laboratorio_7_Parte_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# -	Crear un DataFrame con los nombres, profesión y países de 8 personas, y luego imprimir el DataFrame.

# %%
import pandas as pd
data = {
    'Nombre': ['Fabian', 'Camila', 'Luis', 'Andrea', 'Carlos', 'Daniela', 'Juan', 'Sofia'],
    'Profesión': ['Ingeniero', 'Médica', 'Abogado', 'Arquitecta', 'Contador', 'Diseñadora', 'Maestro', 'Psicóloga'],
    'País': ['Colombia', 'Argentina', 'México', 'Chile', 'Perú', 'Uruguay', 'Paraguay', 'Bolivia']
}
df = pd.DataFrame(data)
print(df)
# Out:
#     Nombre   Profesión       País
# 0   Fabian   Ingeniero   Colombia
# 1   Camila      Médica  Argentina
# 2     Luis     Abogado     México
# 3   Andrea  Arquitecta      Chile
# 4   Carlos    Contador       Perú
# 5  Daniela  Diseñadora    Uruguay
# 6     Juan     Maestro   Paraguay
# 7    Sofia   Psicóloga    Bolivia

# %% [markdown]
# -	Cargar un archivo CSV (puedes usar un archivo de ejemplo en tu entorno) y mostrar las primeras 5 filas.

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df.head(5)
# Out:
#    Duracion  Pulso  Maxpulso  Calorias
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %% [markdown]
# -	Generar un DataFrame con 100 filas y 8 columnas de valores aleatorios, y luego mostrar un resumen estadístico de los datos.

# %%
import pandas as pd
import numpy as np
df= pd.DataFrame(np.random.rand(100,8))
df.describe( )
# Out:
#                 0           1           2           3           4           5  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     0.435348    0.505429    0.540087    0.455594    0.509092    0.515900
# std      0.281057    0.256406    0.255080    0.297434    0.293684    0.269354
# min      0.000470    0.007198    0.042551    0.014033    0.021220    0.003850
# 25%      0.200629    0.320515    0.318810    0.191696    0.249775    0.287297
# 50%      0.371530    0.527319    0.593783    0.423917    0.484341    0.545779
# 75%      0.627324    0.686986    0.745118    0.694274    0.771038    0.706879
# max      0.987720    0.977773    0.996168    0.990105    0.999150    0.998636
#
#                 6           7
# count  100.000000  100.000000
# mean     0.521466    0.541604
# std      0.307231    0.282154
# min      0.029470    0.006284
# 25%      0.233362    0.309416
# 50%      0.540489    0.574425
# 75%      0.814351    0.794068
# max      0.996922    0.985645
